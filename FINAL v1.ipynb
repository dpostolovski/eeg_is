# %% [markdown]
# <a href="https://colab.research.google.com/github/dpostolovski/eeg_is/blob/master/FINAL%20v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#   <img alt="FINKI **LOGO**" height="auto" src="https://www.finki.ukim.mk/Content/dataImages/downloads/logo-large-500x500_2.png" hspace="10px" vspace="0px">
#   <h1>
#     Интелигентни системи - Лабораториска вежба
#   </h1>
#
#   <h3><i>Група 5</i></h3>
#   <h4><i>Дамjан Постоловски, Стефан Тодоровски, Ангела Кралевска, Иван Крстев, Мариjа Величковска</i></h2>
# </center>
#
# ---

# %% [markdown]
# # (1) Подготовка на околината

# %%
#@title 1.1 Монтирање на Google Drive податочниот систем
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#@title 1.2 Инсталирање, вчитување и иницијализација на потребните библиотеки
# !pip install mne 
# !pip install termcolor

# %tensorflow_version 1.12.0

import os
import numpy as np
import matplotlib.pyplot as plt

import mne
from mne.preprocessing import ICA

from sklearn import metrics 
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

from tensorflow.keras.callbacks import ModelCheckpoint 
from tensorflow.keras.utils import to_categorical as to_cat
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K

from scipy.io import loadmat
from collections import Counter
from termcolor import colored

# %cd drive/My\ Drive/Интелигентни\ Системи
from EEGModels import DeepConvNet, EEGNet

# !mkdir saved_models

K.set_image_data_format('channels_first')
# Out:
# Requirement already satisfied: mne in /usr/local/lib/python3.6/dist-packages (0.20.7)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.6/dist-packages (from mne) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from mne) (1.18.5)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.6/dist-packages (1.1.0)
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.12.0`. This will be interpreted as: `1.x`.
#
#
# TensorFlow is already loaded. Please restart the runtime to change versions.
# [Errno 2] No such file or directory: 'drive/My Drive/Интелигентни Системи'
# /content/drive/.shortcut-targets-by-id/1foXUZVE0mxnmx1CREGLvuWb3DEHpgrMB/Интелигентни Системи
# mkdir: cannot create directory ‘saved_models’: File exists

# %% [markdown]
# # (2) Иницијализација на функции и константи

# %%
#@title 2.1 Иницијализација на константи
PARTICIPANT_START = 3 #@param {type:"integer"}
PARTICIPANT_END = 5 #@param {type:"integer"}
NUM_BATCH_SIZE=100 #@param {type:"integer"}
NUM_EPOCHS=150 #@param {type:"integer"}

CH_NAMES = ["C3", "Cz", "C4", "CPz", "P3", "Pz", "P4", "POz"]
CH_TYPES = ['eeg','eeg','eeg','eeg','eeg','eeg','eeg','eeg']
MNE_INFO = mne.create_info(ch_names=CH_NAMES, sfreq=250, ch_types=CH_TYPES)

# %% [markdown]
# ## 2.2 Иницијализација на функции кои ќе ги користиме
# 1. load_mat_data - ги вчитува .mat податоците.
# 2. load_txt_data - ги вчитува .txt податоците.
# 3. load_data - ги повикува претходните две функции и ги вчитува податоците за даден учесник.
# 4. reshape - ја трансформира низата да биде компатибилна со DeepConvNet
# 5. load_runs_per_block - го вчитува бројот на обиди во блоковите за тест податоците
# 6. print_test_data_info - печатење карактеристики на вчитаните тест податоци

# %%
def load_mat_data(folder_path, file_name, mode = 'Train'):
    """
        Load and concatenate train mat data from all three sessions.

        :param folder_path: path to the participant data
        :param file_name: the name of the mat file to be loaded (without .mat extension)
        :param mode: Train or Test data 
        :return: numpy array containing the mat data
    """
    data = np.empty(0)
    for session in range(1, 4):  # Итерација низ секоја сесија
        path = folder_path + '/S' + format(session, '02') + '/' + mode + '/' + file_name + '.mat'
        temp = loadmat(path)[file_name]
        if data.size != 0:
            data = np.concatenate((data, temp), axis=2)
        else:
            data = np.array(temp)
    return data


def load_txt_data(folder_path, file_name, mode = 'Train'):
    """
        Load and concatenate txt data from all three sessions.

        :param folder_path: path to the participant data
        :param file_name: the name of the file to be loaded
        :param mode: Train or Test data 
        :return: numpy array containing the wanted data
    """
    data = np.empty(0)
    for session in range(1, 4):  # Итерација низ секоја сесија
        path = folder_path + '/S' + format(session, '02') + '/' + mode + '/' + file_name
        with open(path, "r") as file:
            temp = file.read().splitlines()
            if file_name == 'trainLabels.txt':
                temp = np.repeat(temp, 8 * 10)
            if data.size != 0:
                data = np.concatenate((data, temp))
            else:
                data = np.array(temp)
    return data


def load_data(participant):
    """
        Load data for the given participant.

        :param participant: Participant number (1-15)
        :return: train_data, train_labels, train_events, train_targets
    """
    print("Вчитување податоци од испитниот примерок (учесник) " + str(participant) + '...')
    path_to_data = 'Data/SBJ' + format(participant, '02')

    train_data = load_mat_data(path_to_data, 'trainData')
    train_labels = load_txt_data(path_to_data, 'trainLabels.txt')
    train_events = load_txt_data(path_to_data, 'trainEvents.txt')
    train_targets = load_txt_data(path_to_data, 'trainTargets.txt')

    train_labels = train_labels.astype(np.int); train_labels = train_labels-1
    train_events = train_events.astype(np.int); train_events = train_events-1

    print("Податоците од испитниот примерок (учесник) " + str(participant) + " се вчитани.\n")
    return train_data, train_labels, train_events, train_targets


def load_test_data(participant):
    """
        Load test data for the given participant.

        :param participant: Participant number (1-15)
        :return: test_date, test_events
    """
    print("Вчитување тест податоци од испитниот примерок (учесник) " + str(participant) + '...')
    path_to_data = 'Data/SBJ' + format(participant, '02')

    test_date = load_mat_data(path_to_data, 'testData', 'Test')
    test_events = load_txt_data(path_to_data, 'testEvents.txt', 'Test')

    print("Тест податоците од испитниот примерок (учесник) " + str(participant) + " се вчитани.\n")
    return test_date, test_events


def reshape(data):
  """
      Swap and reverse swap channels to fit the requirements of the libraries used

      :param data: data array which needs to be reshaped
      :return: reshaped array
  """
  array = np.swapaxes(data, 0, 2) # (канал, епоха, настан) -> (настан, епоха, канал)
  array = np.swapaxes(array, 1, 2) # (настан, епоха, канал) -> (настан, канал, епоха)
  array = array.reshape(array.shape[0], 1, 8, 350) # (настан, 1, епоха, канал)
  return array

def load_runs_per_block(participant):
  """
      Load the runs per block for the given participant

      :param participant: Participant number (1-15)
      :return: Number of runs per block in the test data for the given participant 
  """
  test_runs_per_block = [[i for i in range(3)] for j in range(15)] # Covek, Sesija

  file_name = 'Data/SBJ' + format(participant, '02')
  for j in range(1, 4): # Итерација низ секоја сесија
    file_test_set = 'S' + format(j, '02') + '/Test'

    # Вчитување на бројот на runs 
    full_path = file_name + "/" + file_test_set + "/runs_per_block.txt"
    with open(full_path, "r") as runs_per_block:
      test_runs_per_block[participant-1][j-1] = int(runs_per_block.read())
  
  return test_runs_per_block

def print_test_data_info(participant, test_data, test_events, runs_per_block, predictions, index):
  """
      Visual representation and characteristics of the loaded test data

      :param participant: Participant number (1-15)
      :param test_data: The test data array
      :param test_events: The test events array
      :param runs_per_block: Number of runs per block
      :param predictions: Number of predictions to be made
      :param index: 0 based index for the arrays
  """

  print("SBJ" + str(format(participant, '02')) + "| Test_data: " + str(test_data[index].shape)) # test_data to predict
  print("SBJ" + str(format(participant, '02')) + "| Test_events: " + str(len(test_events))) # test_events
  for session in range (1,4):
    print("SBJ" + str(format(participant, '02')) + " / S" + str(format(session, '02')) + "| Runs per block: " + str(runs_per_block[participant-1][session-1])) # runs per block in SJB01, SJ00 
  print("SBJ" + str(format(participant, '02')) + "| Predictions: " + str(len(predictions)) + '\n')

# %% [markdown]
# # (3) Визуелизација

# %% [markdown]
# За визуелизација ќе користиме само мал дел од податоците, односно поконкретно ќе ги визуелизираме податоците на вториот учесник.

# %%
data, labels, events, targets = load_data(2)

mne_compatible_array = np.swapaxes(data, 0, 1)  # (епоха, канал, настан)
print("(епоха, канал, настан) : " + str(mne_compatible_array.shape))
mne_data = mne.epochs.EpochsArray(mne_compatible_array, MNE_INFO)
# Out:
# Вчитување податоци од испитниот примерок (учесник) 2...
# Податоците од испитниот примерок (учесник) 2 се вчитани.
#
# (епоха, канал, настан) : (350, 8, 4800)
# 350 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# 0 bad epochs dropped

# %% [markdown]
# ## 3.1 Локација на сензорите
# Може да се забележи дека каналите кои ги отчитуваме се наоѓаат во средниот и задниот дел на мозокот.
# Канали кои ги разгледуваме: "C3", "Cz", "C4", "CPz", "P3", "Pz", "P4", "POz"

# %%
montage = mne.channels.make_standard_montage("standard_alphabetic")
montage.plot();
# Out:
# Creating RawArray with float64 data, n_channels=65, n_times=1
#     Range : 0 ... 0 =      0.000 ...     0.000 secs
# Ready.

# %% [markdown]
# ## 3.2 Histogram, изглед на сигналот и зависности помеѓу 8те канали
# За хистограмот и зависноста меѓу 8те канали ќе ги искористиме податоците за првиот учесник од неговата прва сесија.

# %%
fig, axs = plt.subplots(2)
axs[0].hist(data[2][49]) # Хистограм за третиот канал, педесетата епоха
axs[1].plot(range(0, 4800), data[2][175][0:4800]) # Вредноста на сигналот на третиот канал, во 175-тата епоха, во сите настани

k = 0
fig, axs = plt.subplots(8,8)
for i in range(8):
  for y in range(8):
    axs[i,y].plot(data[i][175], data[y][175])

# %% [markdown]
# ## 3.3 Визуелизација на податоците

# %% [markdown]
# ### 3.3.1 Визуелизација на EEG сигналите во рамки на првиот настан (првата слика) и 50-тиот настан (втората слика)

# %%
reshaped_data = np.swapaxes(data, 1, 2) # (канал, настан, епоха).

fig, axs = plt.subplots(8)
for channel in range(0, 8):
  axs[channel].set_title(CH_NAMES[channel])
  for epoch in range(0, 350):
    axs[channel].plot(range(0,350), reshaped_data[channel][0])

fig, axs = plt.subplots(8)
for channel in range(0, 8):
  axs[channel].set_title(CH_NAMES[channel])
  for epoch in range(0, 350):
    axs[channel].plot(range(0,350), reshaped_data[channel][50])

# %% [markdown]
# ### 3.3.2 Визуелизација на EEG сигналите во првата, средната и последната епоха.
# 1. Визуелизација на EEG податоците по канали за првата, средната и последната епоха.
# 2. Power Spectrum Density на 175-тата епоха. Во оваа епоха сигналите би биле најстабилни за објектот кој светка.

# %%
middle_epoch = mne_compatible_array[175]
first_epoch = mne_compatible_array[0]
last_epoch = mne_compatible_array[349]

raw_middle = mne.io.RawArray(middle_epoch, MNE_INFO)
raw_first = mne.io.RawArray(first_epoch, MNE_INFO)
raw_last = mne.io.RawArray(last_epoch, MNE_INFO)

print("\n")
print(colored('====== 1 ======', 'red'))
print(colored("Прва епоха од сите 4800 настани", 'blue'))
raw_first.plot(n_channels=8, scalings=dict(eeg=40), title='EEG Signals',
         show=True, block=True, color = dict(eeg='blue'))
print(colored("Средна епоха од сите 4800 настани", 'blue'))
raw_middle.plot(n_channels=8, scalings=dict(eeg=40), title='EEG Signals',
         show=True, block=True, color = dict(eeg='blue'))
print(colored("Последна епоха од сите 4800 настани", 'blue'))
raw_last.plot(n_channels=8, scalings=dict(eeg=40), title='EEG Signals',
         show=True, block=True, color = dict(eeg='blue'))
print("\n")
print(colored('====== 2 ======', 'red'))
raw_middle.plot_psd(area_mode='range', show=False, average=True);
mne_data.plot_image();
# Out:
# Creating RawArray with float64 data, n_channels=8, n_times=4800
#     Range : 0 ... 4799 =      0.000 ...    19.196 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=4800
#     Range : 0 ... 4799 =      0.000 ...    19.196 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=4800
#     Range : 0 ... 4799 =      0.000 ...    19.196 secs
# Ready.
#
#
# ====== 1 ======
# Прва епоха од сите 4800 настани
# Средна епоха од сите 4800 настани
# Последна епоха од сите 4800 настани
# ====== 2 ======
# Effective window size : 8.192 (s)
# 350 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# 0 bad epochs dropped
# combining channels using "gfp"

# %% [markdown]
# ### 3.3.3 Визуелна споредба на EEG податоците при светкање на првиот и последниот објект
# Во првиот случај вршиме споредба на EEG податоците кога првиот и последниот објект светнал без разлика дали бил target, додека во вториот случај ги споредуваме EEG податоците за случаи само кога тие објекти биле target објекти.

# %%
# Извлекување на настаните каде светнал првиот објект.
first_object_events = [index for index, value in enumerate(events) if value == 0]
first_object_eeg_data = np.zeros((8, 350, len(first_object_events)))
for channel in range(0, 8): # Секој канал
  for epoch in range(0, 350): # Секоја епоха
    i = 0
    for event in first_object_events: # Настан
      first_object_eeg_data[channel][epoch][i] = data[channel][epoch][event]
      i = i+1

# Креирање на соодветна дводимензионална низа за mne библиотеката
mne_first_obj_array = np.swapaxes(first_object_eeg_data, 0, 1) # (епохa, канал, настан).
epoch = mne_first_obj_array[175] 
first_object_raw = mne.io.RawArray(epoch, MNE_INFO)





# Извлекување на настаните каде светнал првиот објект и бил target.
first_object_events_target = [index for index, value in enumerate(events) if value == 0]
for event_pos in first_object_events_target:
  if targets[event_pos] == 1:
    continue # Продолжи
  else:
    first_object_events_target.remove(event_pos) # Избриши -> Објектот не е target
first_object_target_eeg_data = np.zeros((8,350, len(first_object_events_target)))
for channel in range(0, 8): # Секој канал
  for epoch in range(0, 350): # Секоја епоха
    i = 0
    for event in first_object_events_target: # Настан
      first_object_target_eeg_data[channel][epoch][i] = data[channel][epoch][event]
      i = i+1

# Креирање на соодветна дводимензионална низа за mne библиотеката
mne_first_obj_target_array = np.swapaxes(first_object_target_eeg_data, 0, 1) # (епохa, канал, настан).
epoch = mne_first_obj_target_array[175] 
first_object_target_raw = mne.io.RawArray(epoch, MNE_INFO)





# Извлекување на настаните каде светнал последниот објект.
last_object_events = [index for index, value in enumerate(events) if value == 7]
last_object_eeg_data = np.zeros((8,350, len(last_object_events)))
for channel in range(0, 8): # Секој канал
  for epoch in range(0, 350): # Секоја епоха
    i = 0
    for event in last_object_events: # Настан
      last_object_eeg_data[channel][epoch][i] = data[channel][epoch][event]
      i = i+1

# Креирање на соодветна дводимензионална низа за mne библиотеката
mne_last_obj_array = np.swapaxes(last_object_eeg_data, 0, 1) # (епохa, канал, настан).
epoch = mne_last_obj_array[175] 
last_object_raw = mne.io.RawArray(epoch, MNE_INFO)





# Извлекување на настаните каде светнал последниот објект и бил target.
last_object_events_target = [index for index, value in enumerate(events) if value == 7]
for event_pos in last_object_events_target:
  if targets[event_pos] == 1:
    continue # Продолжи
  else:
    last_object_events_target.remove(event_pos) # Избриши -> Објектот не е target
last_object_target_eeg_data = np.zeros((8,350, len(last_object_events_target)))
for channel in range(0, 8): # Секој канал
  for epoch in range(0, 350): # Секоја епоха
    i = 0
    for event in last_object_events_target: # Настан
      last_object_target_eeg_data[channel][epoch][i] = data[channel][epoch][event]
      i = i+1
      
# Креирање на соодветна дводимензионална низа за mne библиотеката
mne_last_obj_target_array = np.swapaxes(last_object_target_eeg_data, 0, 1) # (епохa, канал, настан).
epoch = mne_last_obj_target_array[175] 
last_object_target_raw = mne.io.RawArray(epoch, MNE_INFO)





# Исцртување и печатење
print("\n\n")
print(colored('====== ПРВ ОБЈЕКТ - Книги на полица ======', 'red'))
print(colored("Вкупно светнал: " + str(len(first_object_events)), 'blue'))
print(colored("Вкупно светнал и бил target: " + str(len(first_object_events_target)), 'blue'))
print("\n")
print(colored('====== ПОСЛЕДЕН ОБЈЕКТ - Слика закачена на ѕид ======', 'red'))
print(colored("Вкупно светнал: " + str(len(last_object_events)), 'blue'))
print(colored("Вкупно светнал и бил target: " + str(len(last_object_events_target)), 'blue'))
print("\n")
print(colored('====== Графици со EEG податоци кога светнале првиот и последниот објект  ======', 'green'))
first_object_raw.plot(n_channels=8, scalings=dict(eeg=40), title='EEG Signals',
         show=True, block=True, color = dict(eeg='blue'));
last_object_raw.plot(n_channels=8, scalings=dict(eeg=40), title='EEG Signals',
         show=True, block=True, color = dict(eeg='blue'));
print("\n")
print(colored('====== Графици со EEG податоци кога светнале првиот и последниот објект и биле target  ======', 'green'))
first_object_raw.plot(n_channels=8, scalings=dict(eeg=40), title='EEG Signals',
         show=True, block=True, color = dict(eeg='blue'));
last_object_raw.plot(n_channels=8, scalings=dict(eeg=40), title='EEG Signals',
         show=True, block=True, color = dict(eeg='blue'));
# Out:
# Creating RawArray with float64 data, n_channels=8, n_times=600
#     Range : 0 ... 599 =      0.000 ...     2.396 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=300
#     Range : 0 ... 299 =      0.000 ...     1.196 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=600
#     Range : 0 ... 599 =      0.000 ...     2.396 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=300
#     Range : 0 ... 299 =      0.000 ...     1.196 secs
# Ready.
#
#
#
# ====== ПРВ ОБЈЕКТ - Книги на полица ======
# Вкупно светнал: 600
# Вкупно светнал и бил target: 300
#
#
# ====== ПОСЛЕДЕН ОБЈЕКТ - Слика закачена на ѕид ======
# Вкупно светнал: 600
# Вкупно светнал и бил target: 300
#
#
# ====== Графици со EEG податоци кога светнале првиот и последниот објект  ======
# ====== Графици со EEG податоци кога светнале првиот и последниот објект и биле target  ======

# %%
mne_data.plot_psd(tmin=0.2, tmax=1.2, fmin=0, fmax=60, average=True, spatial_colors=False);
num_components = 8
ica = ICA(n_components=num_components, method='fastica')
ica.fit(mne_data)
ica.plot_sources(mne_data);
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# Fitting ICA to data using 8 channels (please be patient, this may take a while)
# Inferring max_pca_components from picks
# Selecting by number: 8 components
# Fitting ICA took 13.2s.

# %% [markdown]
# # (4) Функции за Претпроцесирање

# %%
#@title 4.1 Стандардизација на податоците
def standardize(mne_compatible_array): 
  standardizer = mne.decoding.Scaler(scalings='mean')
  standardizer.fit(mne_compatible_array)
  standardized_data = standardizer.transform(mne_compatible_array)
  print("(Стандардизација) Просекот е:",-round(standardized_data.mean()))
  print("(Стандардизација) Варијансата е:",round(standardized_data.var()))
  return standardized_data

# %%
#@title 4.2 Отстранување на шум
def noise_removal(mne_compatible_array, mne_data):
  Min, Max = round(mne_compatible_array.min()),round(mne_compatible_array.max())*1000000
  picks = mne.pick_types(mne_data.info, meg=False, eeg=True, stim=False, eog=False)
  # mne.viz.plot_epochs_image(mne_data, picks='eeg', vmin= Min, vmax=Max)
  
  xd = mne.preprocessing.Xdawn(n_components=2, signal_cov=None)
  xd.fit(mne_data)
  noise_removed_data = xd.apply(mne_data)
  # mne.viz.plot_epochs_image(epochs_denoised['1'], picks='eeg', vmin=Min, vmax=Max)
  print(noise_removed_data.keys().shape)
  print(noise_removed_data.shape)
  return noise_removed_data

# %%
#@title 4.3 Principal Component Analysis
def pca(mne_compatible_array, mne_data):
  Min, Max = round(mne_compatible_array.min()),round(mne_compatible_array.max())*1000000
  pca = mne.decoding.UnsupervisedSpatialFilter(PCA(8), average=False)
  pca_data = pca.fit_transform(mne_compatible_array)
  ev = mne.EvokedArray(np.mean(pca_data, axis=0),
                      mne.create_info(8, mne_data.info['sfreq'],
                                      ch_types='eeg'), tmin=Min)
  ev.plot(show=False, window_title="PCA", time_unit='ms')
  print(ev)
  return ev

# %% [markdown]
# # (5) Тренирање на моделот
# Тренирање на моделот

# %%
# Глобална низа каде ќе се зачувуваат тренираните модели
models = []

for participant in range(PARTICIPANT_START, PARTICIPANT_END):  # Итерација низ секој испитен примерок
    train_data, train_labels, train_events, train_targets = load_data(participant)
    
    # Примени функции за претпроцесирање
    mne_compatible_data = np.swapaxes(train_data, 0, 1)  # (епоха, канал, настан)
    mne_data = mne.epochs.EpochsArray(mne_compatible_data, MNE_INFO)
    preprocessed_data = standardize(mne_compatible_data)
    preprocessed_data = pca(mne_compatible_data, mne_data)
    # preprocessed_data = noise_removal(mne_compatible_data, mne_data)
    preprocessed_data = np.swapaxes(train_data, 0, 1) # (канал, епоха, настан)

    preprocessed_data = reshape(train_data) # Трансформирај во форма прифатлива за DeepConvNet

    X_train, X_test, y_train, y_test = train_test_split(preprocessed_data, train_labels, test_size=0.25, random_state=42)

    model = DeepConvNet(nb_classes = 8, Chans = 8, Samples = 350)
    model.compile(loss = 'categorical_crossentropy', metrics=['accuracy'],optimizer = Adam(0.0009))
    checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.basic_mlp.hdf5', 
                                  verbose=1, save_best_only=True)

    y_train = to_cat(y_train)
    y_test = to_cat(y_test)

    model.fit(X_train, y_train, batch_size=NUM_BATCH_SIZE, epochs=NUM_EPOCHS, \
              validation_data=(X_test, y_test),callbacks=[checkpointer], verbose=1)

    score = model.evaluate(X_test, y_test, verbose=1)
    print(score)

    models.append(model)
# Out:
# (8, 350, 4800)
# Вчитување податоци од испитниот примерок (учесник) 3...
# Податоците од испитниот примерок (учесник) 3 се вчитани.
#
# 350 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# 0 bad epochs dropped
# (Стандардизација) Просекот е: -0.0
# (Стандардизација) Варијансата е: 1.0
# <Evoked  |  '' (average, N=1), [-78, -58.804] sec, 8 ch, ~320 kB>
# Version 10
# Version 10
# Version 10
# Version 10
# Version 10
# Version 10
# Version 10
# Train on 3600 samples, validate on 1200 samples
# Epoch 1/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 2.3652 - acc: 0.1662
# Epoch 00001: val_loss improved from inf to 2.21918, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 6s 2ms/sample - loss: 2.3618 - acc: 0.1639 - val_loss: 2.2192 - val_acc: 0.1483
# Epoch 2/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 2.1740 - acc: 0.1957
# Epoch 00002: val_loss improved from 2.21918 to 2.07780, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 586us/sample - loss: 2.1738 - acc: 0.1953 - val_loss: 2.0778 - val_acc: 0.2017
# Epoch 3/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 2.0672 - acc: 0.2249
# Epoch 00003: val_loss did not improve from 2.07780
# 3600/3600 [==============================] - 2s 522us/sample - loss: 2.0682 - acc: 0.2239 - val_loss: 2.4901 - val_acc: 0.1550
# Epoch 4/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 2.0236 - acc: 0.2569
# Epoch 00004: val_loss improved from 2.07780 to 2.01365, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 560us/sample - loss: 2.0217 - acc: 0.2589 - val_loss: 2.0137 - val_acc: 0.2300
# Epoch 5/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 1.9571 - acc: 0.2785
# Epoch 00005: val_loss did not improve from 2.01365
# 3600/3600 [==============================] - 2s 521us/sample - loss: 1.9622 - acc: 0.2800 - val_loss: 2.3138 - val_acc: 0.1900
# Epoch 6/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.8910 - acc: 0.3029
# Epoch 00006: val_loss did not improve from 2.01365
# 3600/3600 [==============================] - 2s 522us/sample - loss: 1.8898 - acc: 0.3019 - val_loss: 2.0419 - val_acc: 0.2200
# Epoch 7/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 1.8820 - acc: 0.2897
# Epoch 00007: val_loss did not improve from 2.01365
# 3600/3600 [==============================] - 2s 527us/sample - loss: 1.8845 - acc: 0.2892 - val_loss: 2.1171 - val_acc: 0.2192
# Epoch 8/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 1.7986 - acc: 0.3303
# Epoch 00008: val_loss did not improve from 2.01365
# 3600/3600 [==============================] - 2s 532us/sample - loss: 1.8026 - acc: 0.3294 - val_loss: 2.0156 - val_acc: 0.2550
# Epoch 9/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.7316 - acc: 0.3537
# Epoch 00009: val_loss did not improve from 2.01365
# 3600/3600 [==============================] - 2s 534us/sample - loss: 1.7370 - acc: 0.3525 - val_loss: 2.2269 - val_acc: 0.2167
# Epoch 10/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 1.7244 - acc: 0.3612
# Epoch 00010: val_loss did not improve from 2.01365
# 3600/3600 [==============================] - 2s 531us/sample - loss: 1.7270 - acc: 0.3592 - val_loss: 2.2314 - val_acc: 0.2325
# Epoch 11/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.6935 - acc: 0.3689
# Epoch 00011: val_loss did not improve from 2.01365
# 3600/3600 [==============================] - 2s 534us/sample - loss: 1.6938 - acc: 0.3700 - val_loss: 2.3660 - val_acc: 0.1975
# Epoch 12/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.6421 - acc: 0.3820
# Epoch 00012: val_loss improved from 2.01365 to 1.93729, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 664us/sample - loss: 1.6410 - acc: 0.3836 - val_loss: 1.9373 - val_acc: 0.2758
# Epoch 13/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 1.6264 - acc: 0.3800
# Epoch 00013: val_loss improved from 1.93729 to 1.82472, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 574us/sample - loss: 1.6318 - acc: 0.3786 - val_loss: 1.8247 - val_acc: 0.3000
# Epoch 14/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.5881 - acc: 0.4040
# Epoch 00014: val_loss did not improve from 1.82472
# 3600/3600 [==============================] - 2s 524us/sample - loss: 1.5943 - acc: 0.4033 - val_loss: 1.9008 - val_acc: 0.3158
# Epoch 15/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.5322 - acc: 0.4251
# Epoch 00015: val_loss did not improve from 1.82472
# 3600/3600 [==============================] - 2s 521us/sample - loss: 1.5318 - acc: 0.4256 - val_loss: 1.9181 - val_acc: 0.2800
# Epoch 16/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 1.5064 - acc: 0.4374
# Epoch 00016: val_loss did not improve from 1.82472
# 3600/3600 [==============================] - 2s 513us/sample - loss: 1.5072 - acc: 0.4372 - val_loss: 1.9372 - val_acc: 0.2958
# Epoch 17/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.4549 - acc: 0.4626
# Epoch 00017: val_loss did not improve from 1.82472
# 3600/3600 [==============================] - 2s 527us/sample - loss: 1.4566 - acc: 0.4622 - val_loss: 2.0405 - val_acc: 0.2792
# Epoch 18/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 1.4255 - acc: 0.4703
# Epoch 00018: val_loss did not improve from 1.82472
# 3600/3600 [==============================] - 2s 519us/sample - loss: 1.4301 - acc: 0.4683 - val_loss: 1.8554 - val_acc: 0.3292
# Epoch 19/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.4347 - acc: 0.4691
# Epoch 00019: val_loss did not improve from 1.82472
# 3600/3600 [==============================] - 2s 517us/sample - loss: 1.4362 - acc: 0.4678 - val_loss: 1.8879 - val_acc: 0.3225
# Epoch 20/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 1.4035 - acc: 0.4759
# Epoch 00020: val_loss improved from 1.82472 to 1.72104, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 643us/sample - loss: 1.4082 - acc: 0.4728 - val_loss: 1.7210 - val_acc: 0.3492
# Epoch 21/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.3467 - acc: 0.5086
# Epoch 00021: val_loss did not improve from 1.72104
# 3600/3600 [==============================] - 2s 516us/sample - loss: 1.3498 - acc: 0.5081 - val_loss: 1.8430 - val_acc: 0.3142
# Epoch 22/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 1.3230 - acc: 0.5079
# Epoch 00022: val_loss did not improve from 1.72104
# 3600/3600 [==============================] - 2s 519us/sample - loss: 1.3193 - acc: 0.5081 - val_loss: 1.7897 - val_acc: 0.3333
# Epoch 23/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 1.2998 - acc: 0.5141
# Epoch 00023: val_loss improved from 1.72104 to 1.71837, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 559us/sample - loss: 1.3005 - acc: 0.5153 - val_loss: 1.7184 - val_acc: 0.3642
# Epoch 24/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.2831 - acc: 0.5229
# Epoch 00024: val_loss improved from 1.71837 to 1.57133, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 570us/sample - loss: 1.2833 - acc: 0.5233 - val_loss: 1.5713 - val_acc: 0.4192
# Epoch 25/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.2475 - acc: 0.5331
# Epoch 00025: val_loss did not improve from 1.57133
# 3600/3600 [==============================] - 2s 520us/sample - loss: 1.2496 - acc: 0.5317 - val_loss: 1.7236 - val_acc: 0.3775
# Epoch 26/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 1.2503 - acc: 0.5332
# Epoch 00026: val_loss did not improve from 1.57133
# 3600/3600 [==============================] - 2s 519us/sample - loss: 1.2503 - acc: 0.5333 - val_loss: 2.1227 - val_acc: 0.2875
# Epoch 27/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.1948 - acc: 0.5623
# Epoch 00027: val_loss did not improve from 1.57133
# 3600/3600 [==============================] - 2s 522us/sample - loss: 1.1942 - acc: 0.5608 - val_loss: 1.6373 - val_acc: 0.4150
# Epoch 28/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.1741 - acc: 0.5706
# Epoch 00028: val_loss improved from 1.57133 to 1.51316, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 577us/sample - loss: 1.1729 - acc: 0.5697 - val_loss: 1.5132 - val_acc: 0.4408
# Epoch 29/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.1235 - acc: 0.5931
# Epoch 00029: val_loss did not improve from 1.51316
# 3600/3600 [==============================] - 2s 525us/sample - loss: 1.1285 - acc: 0.5900 - val_loss: 1.5374 - val_acc: 0.4308
# Epoch 30/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.1173 - acc: 0.5869
# Epoch 00030: val_loss did not improve from 1.51316
# 3600/3600 [==============================] - 2s 517us/sample - loss: 1.1145 - acc: 0.5886 - val_loss: 1.5696 - val_acc: 0.4200
# Epoch 31/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.0865 - acc: 0.6091
# Epoch 00031: val_loss did not improve from 1.51316
# 3600/3600 [==============================] - 2s 513us/sample - loss: 1.0913 - acc: 0.6064 - val_loss: 1.5250 - val_acc: 0.4500
# Epoch 32/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.0807 - acc: 0.6080
# Epoch 00032: val_loss improved from 1.51316 to 1.49293, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 563us/sample - loss: 1.0831 - acc: 0.6081 - val_loss: 1.4929 - val_acc: 0.4450
# Epoch 33/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 1.0260 - acc: 0.6297
# Epoch 00033: val_loss improved from 1.49293 to 1.42144, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 565us/sample - loss: 1.0280 - acc: 0.6294 - val_loss: 1.4214 - val_acc: 0.4558
# Epoch 34/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.9726 - acc: 0.6591
# Epoch 00034: val_loss improved from 1.42144 to 1.33420, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 561us/sample - loss: 0.9755 - acc: 0.6569 - val_loss: 1.3342 - val_acc: 0.4917
# Epoch 35/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.9828 - acc: 0.6494
# Epoch 00035: val_loss improved from 1.33420 to 1.28034, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 559us/sample - loss: 0.9864 - acc: 0.6478 - val_loss: 1.2803 - val_acc: 0.5150
# Epoch 36/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.9559 - acc: 0.6614
# Epoch 00036: val_loss did not improve from 1.28034
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.9545 - acc: 0.6608 - val_loss: 1.3722 - val_acc: 0.4892
# Epoch 37/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.9317 - acc: 0.6657
# Epoch 00037: val_loss did not improve from 1.28034
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.9312 - acc: 0.6661 - val_loss: 1.4670 - val_acc: 0.4458
# Epoch 38/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.9295 - acc: 0.6686
# Epoch 00038: val_loss improved from 1.28034 to 1.28003, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 558us/sample - loss: 0.9296 - acc: 0.6678 - val_loss: 1.2800 - val_acc: 0.5200
# Epoch 39/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.9071 - acc: 0.6809
# Epoch 00039: val_loss improved from 1.28003 to 1.23461, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 557us/sample - loss: 0.9095 - acc: 0.6794 - val_loss: 1.2346 - val_acc: 0.5192
# Epoch 40/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.8660 - acc: 0.6865
# Epoch 00040: val_loss did not improve from 1.23461
# 3600/3600 [==============================] - 2s 519us/sample - loss: 0.8687 - acc: 0.6867 - val_loss: 1.3508 - val_acc: 0.4867
# Epoch 41/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.8717 - acc: 0.6903
# Epoch 00041: val_loss did not improve from 1.23461
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.8701 - acc: 0.6894 - val_loss: 1.2850 - val_acc: 0.5125
# Epoch 42/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.8413 - acc: 0.6949
# Epoch 00042: val_loss did not improve from 1.23461
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.8413 - acc: 0.6947 - val_loss: 1.2450 - val_acc: 0.5258
# Epoch 43/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.8318 - acc: 0.7009
# Epoch 00043: val_loss improved from 1.23461 to 1.13831, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 560us/sample - loss: 0.8363 - acc: 0.6992 - val_loss: 1.1383 - val_acc: 0.5617
# Epoch 44/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.7873 - acc: 0.7203
# Epoch 00044: val_loss did not improve from 1.13831
# 3600/3600 [==============================] - 2s 520us/sample - loss: 0.7944 - acc: 0.7169 - val_loss: 1.1715 - val_acc: 0.5742
# Epoch 45/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.7674 - acc: 0.7329
# Epoch 00045: val_loss improved from 1.13831 to 1.08852, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 555us/sample - loss: 0.7719 - acc: 0.7306 - val_loss: 1.0885 - val_acc: 0.5900
# Epoch 46/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.7723 - acc: 0.7263
# Epoch 00046: val_loss improved from 1.08852 to 1.07986, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 563us/sample - loss: 0.7727 - acc: 0.7281 - val_loss: 1.0799 - val_acc: 0.6050
# Epoch 47/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.7361 - acc: 0.7347
# Epoch 00047: val_loss improved from 1.07986 to 1.01005, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 557us/sample - loss: 0.7394 - acc: 0.7333 - val_loss: 1.0101 - val_acc: 0.6392
# Epoch 48/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.7306 - acc: 0.7523
# Epoch 00048: val_loss improved from 1.01005 to 0.97814, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 561us/sample - loss: 0.7277 - acc: 0.7542 - val_loss: 0.9781 - val_acc: 0.6558
# Epoch 49/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.6978 - acc: 0.7615
# Epoch 00049: val_loss improved from 0.97814 to 0.94254, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 558us/sample - loss: 0.7055 - acc: 0.7586 - val_loss: 0.9425 - val_acc: 0.6508
# Epoch 50/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.6811 - acc: 0.7671
# Epoch 00050: val_loss did not improve from 0.94254
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.6823 - acc: 0.7664 - val_loss: 1.0096 - val_acc: 0.6092
# Epoch 51/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.6652 - acc: 0.7765
# Epoch 00051: val_loss did not improve from 0.94254
# 3600/3600 [==============================] - 2s 519us/sample - loss: 0.6681 - acc: 0.7756 - val_loss: 0.9636 - val_acc: 0.6442
# Epoch 52/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.6880 - acc: 0.7656
# Epoch 00052: val_loss did not improve from 0.94254
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.6890 - acc: 0.7647 - val_loss: 1.0160 - val_acc: 0.6200
# Epoch 53/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.6495 - acc: 0.7732
# Epoch 00053: val_loss improved from 0.94254 to 0.87606, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 555us/sample - loss: 0.6565 - acc: 0.7697 - val_loss: 0.8761 - val_acc: 0.6858
# Epoch 54/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.6293 - acc: 0.7847
# Epoch 00054: val_loss did not improve from 0.87606
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.6328 - acc: 0.7836 - val_loss: 0.8854 - val_acc: 0.6783
# Epoch 55/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.6371 - acc: 0.7809
# Epoch 00055: val_loss improved from 0.87606 to 0.80139, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 554us/sample - loss: 0.6403 - acc: 0.7800 - val_loss: 0.8014 - val_acc: 0.7250
# Epoch 56/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.6005 - acc: 0.7974
# Epoch 00056: val_loss did not improve from 0.80139
# 3600/3600 [==============================] - 2s 526us/sample - loss: 0.5993 - acc: 0.7981 - val_loss: 0.9431 - val_acc: 0.6550
# Epoch 57/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.6154 - acc: 0.7911
# Epoch 00057: val_loss did not improve from 0.80139
# 3600/3600 [==============================] - 2s 529us/sample - loss: 0.6187 - acc: 0.7894 - val_loss: 0.8266 - val_acc: 0.7075
# Epoch 58/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.5779 - acc: 0.8020
# Epoch 00058: val_loss did not improve from 0.80139
# 3600/3600 [==============================] - 2s 525us/sample - loss: 0.5776 - acc: 0.8025 - val_loss: 0.8417 - val_acc: 0.7050
# Epoch 59/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.5862 - acc: 0.8066
# Epoch 00059: val_loss improved from 0.80139 to 0.78315, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 562us/sample - loss: 0.5890 - acc: 0.8039 - val_loss: 0.7832 - val_acc: 0.7300
# Epoch 60/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.5735 - acc: 0.8100
# Epoch 00060: val_loss improved from 0.78315 to 0.74971, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 559us/sample - loss: 0.5740 - acc: 0.8100 - val_loss: 0.7497 - val_acc: 0.7417
# Epoch 61/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.5352 - acc: 0.8253
# Epoch 00061: val_loss did not improve from 0.74971
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.5428 - acc: 0.8222 - val_loss: 0.7782 - val_acc: 0.7233
# Epoch 62/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.5256 - acc: 0.8253
# Epoch 00062: val_loss did not improve from 0.74971
# 3600/3600 [==============================] - 2s 531us/sample - loss: 0.5234 - acc: 0.8253 - val_loss: 0.7734 - val_acc: 0.7233
# Epoch 63/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.5174 - acc: 0.8337
# Epoch 00063: val_loss did not improve from 0.74971
# 3600/3600 [==============================] - 2s 527us/sample - loss: 0.5192 - acc: 0.8325 - val_loss: 0.7692 - val_acc: 0.7292
# Epoch 64/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.5122 - acc: 0.8338
# Epoch 00064: val_loss improved from 0.74971 to 0.73058, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 558us/sample - loss: 0.5118 - acc: 0.8350 - val_loss: 0.7306 - val_acc: 0.7300
# Epoch 65/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.4720 - acc: 0.8494
# Epoch 00065: val_loss improved from 0.73058 to 0.70835, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 582us/sample - loss: 0.4763 - acc: 0.8486 - val_loss: 0.7084 - val_acc: 0.7508
# Epoch 66/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.4552 - acc: 0.8603
# Epoch 00066: val_loss did not improve from 0.70835
# 3600/3600 [==============================] - 2s 523us/sample - loss: 0.4557 - acc: 0.8608 - val_loss: 0.7192 - val_acc: 0.7525
# Epoch 67/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.4783 - acc: 0.8437
# Epoch 00067: val_loss improved from 0.70835 to 0.68487, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 562us/sample - loss: 0.4783 - acc: 0.8431 - val_loss: 0.6849 - val_acc: 0.7683
# Epoch 68/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.4514 - acc: 0.8562
# Epoch 00068: val_loss did not improve from 0.68487
# 3600/3600 [==============================] - 2s 519us/sample - loss: 0.4536 - acc: 0.8556 - val_loss: 0.7295 - val_acc: 0.7425
# Epoch 69/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.4582 - acc: 0.8489
# Epoch 00069: val_loss improved from 0.68487 to 0.59244, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 561us/sample - loss: 0.4582 - acc: 0.8503 - val_loss: 0.5924 - val_acc: 0.8083
# Epoch 70/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.4318 - acc: 0.8666
# Epoch 00070: val_loss did not improve from 0.59244
# 3600/3600 [==============================] - 2s 520us/sample - loss: 0.4299 - acc: 0.8681 - val_loss: 0.6089 - val_acc: 0.7975
# Epoch 71/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.4213 - acc: 0.8644
# Epoch 00071: val_loss did not improve from 0.59244
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.4214 - acc: 0.8661 - val_loss: 0.6536 - val_acc: 0.7650
# Epoch 72/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.4273 - acc: 0.8600
# Epoch 00072: val_loss did not improve from 0.59244
# 3600/3600 [==============================] - 2s 522us/sample - loss: 0.4280 - acc: 0.8597 - val_loss: 0.6531 - val_acc: 0.7767
# Epoch 73/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.4441 - acc: 0.8523
# Epoch 00073: val_loss improved from 0.59244 to 0.57646, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 620us/sample - loss: 0.4462 - acc: 0.8514 - val_loss: 0.5765 - val_acc: 0.8075
# Epoch 74/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.3982 - acc: 0.8724
# Epoch 00074: val_loss did not improve from 0.57646
# 3600/3600 [==============================] - 2s 515us/sample - loss: 0.4017 - acc: 0.8711 - val_loss: 0.6232 - val_acc: 0.7892
# Epoch 75/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.4314 - acc: 0.8588
# Epoch 00075: val_loss did not improve from 0.57646
# 3600/3600 [==============================] - 2s 514us/sample - loss: 0.4286 - acc: 0.8603 - val_loss: 0.6294 - val_acc: 0.7717
# Epoch 76/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.3902 - acc: 0.8747
# Epoch 00076: val_loss did not improve from 0.57646
# 3600/3600 [==============================] - 2s 513us/sample - loss: 0.3916 - acc: 0.8747 - val_loss: 0.5883 - val_acc: 0.7992
# Epoch 77/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.4074 - acc: 0.8724
# Epoch 00077: val_loss improved from 0.57646 to 0.55191, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 555us/sample - loss: 0.4083 - acc: 0.8731 - val_loss: 0.5519 - val_acc: 0.8308
# Epoch 78/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.3967 - acc: 0.8703
# Epoch 00078: val_loss did not improve from 0.55191
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.4000 - acc: 0.8686 - val_loss: 0.5673 - val_acc: 0.8083
# Epoch 79/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.3823 - acc: 0.8817
# Epoch 00079: val_loss improved from 0.55191 to 0.51768, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 557us/sample - loss: 0.3831 - acc: 0.8817 - val_loss: 0.5177 - val_acc: 0.8275
# Epoch 80/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.3601 - acc: 0.8941
# Epoch 00080: val_loss improved from 0.51768 to 0.51107, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 561us/sample - loss: 0.3599 - acc: 0.8942 - val_loss: 0.5111 - val_acc: 0.8392
# Epoch 81/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.3464 - acc: 0.8938
# Epoch 00081: val_loss did not improve from 0.51107
# 3600/3600 [==============================] - 2s 513us/sample - loss: 0.3487 - acc: 0.8922 - val_loss: 0.5190 - val_acc: 0.8233
# Epoch 82/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.3654 - acc: 0.8849
# Epoch 00082: val_loss improved from 0.51107 to 0.49816, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 556us/sample - loss: 0.3647 - acc: 0.8850 - val_loss: 0.4982 - val_acc: 0.8475
# Epoch 83/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.3514 - acc: 0.8912
# Epoch 00083: val_loss improved from 0.49816 to 0.46642, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 557us/sample - loss: 0.3553 - acc: 0.8894 - val_loss: 0.4664 - val_acc: 0.8542
# Epoch 84/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.3674 - acc: 0.8853
# Epoch 00084: val_loss did not improve from 0.46642
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.3655 - acc: 0.8858 - val_loss: 0.5021 - val_acc: 0.8392
# Epoch 85/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.3535 - acc: 0.8876
# Epoch 00085: val_loss did not improve from 0.46642
# 3600/3600 [==============================] - 2s 514us/sample - loss: 0.3507 - acc: 0.8886 - val_loss: 0.4911 - val_acc: 0.8342
# Epoch 86/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.3377 - acc: 0.9020
# Epoch 00086: val_loss improved from 0.46642 to 0.46096, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 560us/sample - loss: 0.3423 - acc: 0.9000 - val_loss: 0.4610 - val_acc: 0.8583
# Epoch 87/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.3310 - acc: 0.9006
# Epoch 00087: val_loss improved from 0.46096 to 0.43286, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 558us/sample - loss: 0.3317 - acc: 0.9003 - val_loss: 0.4329 - val_acc: 0.8742
# Epoch 88/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.3166 - acc: 0.9054
# Epoch 00088: val_loss improved from 0.43286 to 0.43226, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 559us/sample - loss: 0.3166 - acc: 0.9056 - val_loss: 0.4323 - val_acc: 0.8708
# Epoch 89/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.3078 - acc: 0.9044
# Epoch 00089: val_loss did not improve from 0.43226
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.3063 - acc: 0.9061 - val_loss: 0.4490 - val_acc: 0.8608
# Epoch 90/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.3050 - acc: 0.9097
# Epoch 00090: val_loss improved from 0.43226 to 0.38268, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 562us/sample - loss: 0.3031 - acc: 0.9103 - val_loss: 0.3827 - val_acc: 0.8892
# Epoch 91/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.3086 - acc: 0.9037
# Epoch 00091: val_loss did not improve from 0.38268
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.3105 - acc: 0.9028 - val_loss: 0.4066 - val_acc: 0.8817
# Epoch 92/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.3114 - acc: 0.9037
# Epoch 00092: val_loss improved from 0.38268 to 0.37139, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 553us/sample - loss: 0.3077 - acc: 0.9056 - val_loss: 0.3714 - val_acc: 0.8958
# Epoch 93/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2899 - acc: 0.9171
# Epoch 00093: val_loss did not improve from 0.37139
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.2920 - acc: 0.9150 - val_loss: 0.4280 - val_acc: 0.8700
# Epoch 94/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.3241 - acc: 0.8949
# Epoch 00094: val_loss did not improve from 0.37139
# 3600/3600 [==============================] - 2s 520us/sample - loss: 0.3256 - acc: 0.8939 - val_loss: 0.4373 - val_acc: 0.8600
# Epoch 95/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.3126 - acc: 0.9068
# Epoch 00095: val_loss did not improve from 0.37139
# 3600/3600 [==============================] - 2s 515us/sample - loss: 0.3110 - acc: 0.9075 - val_loss: 0.3941 - val_acc: 0.8775
# Epoch 96/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.3030 - acc: 0.9026
# Epoch 00096: val_loss did not improve from 0.37139
# 3600/3600 [==============================] - 2s 522us/sample - loss: 0.3057 - acc: 0.9019 - val_loss: 0.4075 - val_acc: 0.8667
# Epoch 97/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2834 - acc: 0.9111
# Epoch 00097: val_loss did not improve from 0.37139
# 3600/3600 [==============================] - 2s 519us/sample - loss: 0.2827 - acc: 0.9111 - val_loss: 0.4145 - val_acc: 0.8625
# Epoch 98/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2868 - acc: 0.9126
# Epoch 00098: val_loss did not improve from 0.37139
# 3600/3600 [==============================] - 2s 514us/sample - loss: 0.2871 - acc: 0.9125 - val_loss: 0.4011 - val_acc: 0.8725
# Epoch 99/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2834 - acc: 0.9109
# Epoch 00099: val_loss did not improve from 0.37139
# 3600/3600 [==============================] - 2s 513us/sample - loss: 0.2831 - acc: 0.9108 - val_loss: 0.3720 - val_acc: 0.8842
# Epoch 100/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2684 - acc: 0.9232
# Epoch 00100: val_loss did not improve from 0.37139
# 3600/3600 [==============================] - 2s 515us/sample - loss: 0.2716 - acc: 0.9219 - val_loss: 0.3997 - val_acc: 0.8742
# Epoch 101/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2729 - acc: 0.9156
# Epoch 00101: val_loss did not improve from 0.37139
# 3600/3600 [==============================] - 2s 522us/sample - loss: 0.2706 - acc: 0.9172 - val_loss: 0.4043 - val_acc: 0.8683
# Epoch 102/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2731 - acc: 0.9154
# Epoch 00102: val_loss did not improve from 0.37139
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2746 - acc: 0.9139 - val_loss: 0.4145 - val_acc: 0.8800
# Epoch 103/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2909 - acc: 0.9091
# Epoch 00103: val_loss did not improve from 0.37139
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.2910 - acc: 0.9100 - val_loss: 0.3838 - val_acc: 0.8833
# Epoch 104/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2824 - acc: 0.9154
# Epoch 00104: val_loss did not improve from 0.37139
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2839 - acc: 0.9150 - val_loss: 0.3946 - val_acc: 0.8583
# Epoch 105/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2663 - acc: 0.9177
# Epoch 00105: val_loss improved from 0.37139 to 0.32695, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 648us/sample - loss: 0.2679 - acc: 0.9178 - val_loss: 0.3269 - val_acc: 0.9000
# Epoch 106/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2690 - acc: 0.9131
# Epoch 00106: val_loss did not improve from 0.32695
# 3600/3600 [==============================] - 2s 521us/sample - loss: 0.2707 - acc: 0.9122 - val_loss: 0.3583 - val_acc: 0.8917
# Epoch 107/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2596 - acc: 0.9249
# Epoch 00107: val_loss improved from 0.32695 to 0.32170, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 555us/sample - loss: 0.2605 - acc: 0.9250 - val_loss: 0.3217 - val_acc: 0.9042
# Epoch 108/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2566 - acc: 0.9191
# Epoch 00108: val_loss did not improve from 0.32170
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2558 - acc: 0.9197 - val_loss: 0.3420 - val_acc: 0.8933
# Epoch 109/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2625 - acc: 0.9191
# Epoch 00109: val_loss did not improve from 0.32170
# 3600/3600 [==============================] - 2s 515us/sample - loss: 0.2606 - acc: 0.9206 - val_loss: 0.3774 - val_acc: 0.8883
# Epoch 110/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2488 - acc: 0.9257
# Epoch 00110: val_loss improved from 0.32170 to 0.31766, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 559us/sample - loss: 0.2480 - acc: 0.9258 - val_loss: 0.3177 - val_acc: 0.9117
# Epoch 111/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2617 - acc: 0.9226
# Epoch 00111: val_loss did not improve from 0.31766
# 3600/3600 [==============================] - 2s 522us/sample - loss: 0.2602 - acc: 0.9233 - val_loss: 0.3527 - val_acc: 0.9008
# Epoch 112/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2577 - acc: 0.9140
# Epoch 00112: val_loss did not improve from 0.31766
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.2559 - acc: 0.9150 - val_loss: 0.3242 - val_acc: 0.9100
# Epoch 113/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2562 - acc: 0.9197
# Epoch 00113: val_loss did not improve from 0.31766
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2573 - acc: 0.9189 - val_loss: 0.3682 - val_acc: 0.8842
# Epoch 114/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2532 - acc: 0.9163
# Epoch 00114: val_loss improved from 0.31766 to 0.29329, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 559us/sample - loss: 0.2533 - acc: 0.9158 - val_loss: 0.2933 - val_acc: 0.9175
# Epoch 115/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2472 - acc: 0.9243
# Epoch 00115: val_loss improved from 0.29329 to 0.29318, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 554us/sample - loss: 0.2466 - acc: 0.9244 - val_loss: 0.2932 - val_acc: 0.9167
# Epoch 116/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2299 - acc: 0.9320
# Epoch 00116: val_loss did not improve from 0.29318
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2301 - acc: 0.9325 - val_loss: 0.2967 - val_acc: 0.9125
# Epoch 117/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2234 - acc: 0.9365
# Epoch 00117: val_loss did not improve from 0.29318
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2250 - acc: 0.9369 - val_loss: 0.4063 - val_acc: 0.8658
# Epoch 118/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2223 - acc: 0.9386
# Epoch 00118: val_loss did not improve from 0.29318
# 3600/3600 [==============================] - 2s 512us/sample - loss: 0.2217 - acc: 0.9392 - val_loss: 0.3138 - val_acc: 0.9075
# Epoch 119/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2290 - acc: 0.9253
# Epoch 00119: val_loss did not improve from 0.29318
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.2268 - acc: 0.9264 - val_loss: 0.3558 - val_acc: 0.8908
# Epoch 120/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2235 - acc: 0.9321
# Epoch 00120: val_loss did not improve from 0.29318
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.2203 - acc: 0.9339 - val_loss: 0.3149 - val_acc: 0.9042
# Epoch 121/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2364 - acc: 0.9250
# Epoch 00121: val_loss did not improve from 0.29318
# 3600/3600 [==============================] - 2s 521us/sample - loss: 0.2384 - acc: 0.9236 - val_loss: 0.3320 - val_acc: 0.8958
# Epoch 122/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2161 - acc: 0.9371
# Epoch 00122: val_loss did not improve from 0.29318
# 3600/3600 [==============================] - 2s 519us/sample - loss: 0.2144 - acc: 0.9381 - val_loss: 0.3024 - val_acc: 0.9167
# Epoch 123/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2127 - acc: 0.9318
# Epoch 00123: val_loss improved from 0.29318 to 0.26634, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 622us/sample - loss: 0.2136 - acc: 0.9325 - val_loss: 0.2663 - val_acc: 0.9200
# Epoch 124/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2202 - acc: 0.9314
# Epoch 00124: val_loss did not improve from 0.26634
# 3600/3600 [==============================] - 2s 512us/sample - loss: 0.2229 - acc: 0.9303 - val_loss: 0.3401 - val_acc: 0.8850
# Epoch 125/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2062 - acc: 0.9403
# Epoch 00125: val_loss improved from 0.26634 to 0.25676, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 560us/sample - loss: 0.2064 - acc: 0.9400 - val_loss: 0.2568 - val_acc: 0.9242
# Epoch 126/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2166 - acc: 0.9347
# Epoch 00126: val_loss did not improve from 0.25676
# 3600/3600 [==============================] - 2s 514us/sample - loss: 0.2192 - acc: 0.9333 - val_loss: 0.2962 - val_acc: 0.9033
# Epoch 127/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2244 - acc: 0.9303
# Epoch 00127: val_loss did not improve from 0.25676
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.2217 - acc: 0.9319 - val_loss: 0.3205 - val_acc: 0.9050
# Epoch 128/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2142 - acc: 0.9331
# Epoch 00128: val_loss did not improve from 0.25676
# 3600/3600 [==============================] - 2s 514us/sample - loss: 0.2146 - acc: 0.9328 - val_loss: 0.2765 - val_acc: 0.9233
# Epoch 129/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2150 - acc: 0.9385
# Epoch 00129: val_loss did not improve from 0.25676
# 3600/3600 [==============================] - 2s 521us/sample - loss: 0.2151 - acc: 0.9386 - val_loss: 0.2966 - val_acc: 0.9142
# Epoch 130/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2185 - acc: 0.9338
# Epoch 00130: val_loss did not improve from 0.25676
# 3600/3600 [==============================] - 2s 511us/sample - loss: 0.2196 - acc: 0.9339 - val_loss: 0.2708 - val_acc: 0.9208
# Epoch 131/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2118 - acc: 0.9409
# Epoch 00131: val_loss did not improve from 0.25676
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2172 - acc: 0.9389 - val_loss: 0.2996 - val_acc: 0.9133
# Epoch 132/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2190 - acc: 0.9312
# Epoch 00132: val_loss did not improve from 0.25676
# 3600/3600 [==============================] - 2s 515us/sample - loss: 0.2201 - acc: 0.9308 - val_loss: 0.2964 - val_acc: 0.9125
# Epoch 133/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2118 - acc: 0.9391
# Epoch 00133: val_loss did not improve from 0.25676
# 3600/3600 [==============================] - 2s 515us/sample - loss: 0.2171 - acc: 0.9369 - val_loss: 0.2582 - val_acc: 0.9192
# Epoch 134/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.1968 - acc: 0.9454
# Epoch 00134: val_loss improved from 0.25676 to 0.24194, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 642us/sample - loss: 0.1966 - acc: 0.9447 - val_loss: 0.2419 - val_acc: 0.9342
# Epoch 135/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.1995 - acc: 0.9438
# Epoch 00135: val_loss did not improve from 0.24194
# 3600/3600 [==============================] - 2s 513us/sample - loss: 0.2004 - acc: 0.9425 - val_loss: 0.3359 - val_acc: 0.8950
# Epoch 136/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2157 - acc: 0.9377
# Epoch 00136: val_loss did not improve from 0.24194
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2146 - acc: 0.9378 - val_loss: 0.2811 - val_acc: 0.9117
# Epoch 137/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2129 - acc: 0.9320
# Epoch 00137: val_loss did not improve from 0.24194
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.2134 - acc: 0.9322 - val_loss: 0.2727 - val_acc: 0.9175
# Epoch 138/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2218 - acc: 0.9331
# Epoch 00138: val_loss improved from 0.24194 to 0.22374, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 554us/sample - loss: 0.2225 - acc: 0.9328 - val_loss: 0.2237 - val_acc: 0.9442
# Epoch 139/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2099 - acc: 0.9365
# Epoch 00139: val_loss did not improve from 0.22374
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.2118 - acc: 0.9361 - val_loss: 0.2735 - val_acc: 0.9183
# Epoch 140/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.1999 - acc: 0.9412
# Epoch 00140: val_loss did not improve from 0.22374
# 3600/3600 [==============================] - 2s 515us/sample - loss: 0.2030 - acc: 0.9403 - val_loss: 0.2845 - val_acc: 0.9142
# Epoch 141/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.1827 - acc: 0.9500
# Epoch 00141: val_loss did not improve from 0.22374
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.1821 - acc: 0.9500 - val_loss: 0.2387 - val_acc: 0.9358
# Epoch 142/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.1754 - acc: 0.9509
# Epoch 00142: val_loss did not improve from 0.22374
# 3600/3600 [==============================] - 2s 521us/sample - loss: 0.1736 - acc: 0.9514 - val_loss: 0.2779 - val_acc: 0.9192
# Epoch 143/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.1785 - acc: 0.9451
# Epoch 00143: val_loss did not improve from 0.22374
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.1796 - acc: 0.9456 - val_loss: 0.2730 - val_acc: 0.9150
# Epoch 144/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.1833 - acc: 0.9463
# Epoch 00144: val_loss did not improve from 0.22374
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.1851 - acc: 0.9453 - val_loss: 0.2531 - val_acc: 0.9325
# Epoch 145/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.1988 - acc: 0.9376
# Epoch 00145: val_loss did not improve from 0.22374
# 3600/3600 [==============================] - 2s 520us/sample - loss: 0.1980 - acc: 0.9389 - val_loss: 0.2824 - val_acc: 0.9092
# Epoch 146/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.1967 - acc: 0.9388
# Epoch 00146: val_loss did not improve from 0.22374
# 3600/3600 [==============================] - 2s 519us/sample - loss: 0.1984 - acc: 0.9386 - val_loss: 0.2470 - val_acc: 0.9317
# Epoch 147/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.1953 - acc: 0.9379
# Epoch 00147: val_loss did not improve from 0.22374
# 3600/3600 [==============================] - 2s 513us/sample - loss: 0.1972 - acc: 0.9375 - val_loss: 0.3851 - val_acc: 0.8650
# Epoch 148/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2021 - acc: 0.9400
# Epoch 00148: val_loss did not improve from 0.22374
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.2028 - acc: 0.9397 - val_loss: 0.2473 - val_acc: 0.9217
# Epoch 149/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2094 - acc: 0.9353
# Epoch 00149: val_loss did not improve from 0.22374
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.2108 - acc: 0.9339 - val_loss: 0.2731 - val_acc: 0.9233
# Epoch 150/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.1999 - acc: 0.9353
# Epoch 00150: val_loss did not improve from 0.22374
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.1996 - acc: 0.9358 - val_loss: 0.2722 - val_acc: 0.9150
# 1200/1200 [==============================] - 0s 256us/sample - loss: 0.2722 - acc: 0.9150
# [0.27224805295467375, 0.915]
# Вчитување податоци од испитниот примерок (учесник) 4...
# Податоците од испитниот примерок (учесник) 4 се вчитани.
#
# 350 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# 0 bad epochs dropped
# (Стандардизација) Просекот е: -0.0
# (Стандардизација) Варијансата е: 1.0
# <Evoked  |  '' (average, N=1), [-2156, -2136.8] sec, 8 ch, ~320 kB>
# Version 10
# Version 10
# Version 10
# Version 10
# Version 10
# Version 10
# Version 10
# Train on 3600 samples, validate on 1200 samples
# Epoch 1/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 2.3360 - acc: 0.1441
# Epoch 00001: val_loss improved from inf to 2.28167, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 6s 2ms/sample - loss: 2.3274 - acc: 0.1461 - val_loss: 2.2817 - val_acc: 0.1383
# Epoch 2/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 2.2334 - acc: 0.1654
# Epoch 00002: val_loss improved from 2.28167 to 2.11905, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 560us/sample - loss: 2.2278 - acc: 0.1647 - val_loss: 2.1190 - val_acc: 0.1408
# Epoch 3/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 2.2181 - acc: 0.1682
# Epoch 00003: val_loss did not improve from 2.11905
# 3600/3600 [==============================] - 2s 514us/sample - loss: 2.2162 - acc: 0.1667 - val_loss: 2.2795 - val_acc: 0.1492
# Epoch 4/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 2.1865 - acc: 0.1721
# Epoch 00004: val_loss did not improve from 2.11905
# 3600/3600 [==============================] - 2s 517us/sample - loss: 2.1934 - acc: 0.1706 - val_loss: 2.2374 - val_acc: 0.1850
# Epoch 5/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 2.1346 - acc: 0.1777
# Epoch 00005: val_loss did not improve from 2.11905
# 3600/3600 [==============================] - 2s 517us/sample - loss: 2.1390 - acc: 0.1789 - val_loss: 2.3580 - val_acc: 0.1908
# Epoch 6/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 2.1274 - acc: 0.1938
# Epoch 00006: val_loss improved from 2.11905 to 2.07105, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 564us/sample - loss: 2.1264 - acc: 0.1928 - val_loss: 2.0710 - val_acc: 0.1250
# Epoch 7/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 2.1075 - acc: 0.1971
# Epoch 00007: val_loss did not improve from 2.07105
# 3600/3600 [==============================] - 2s 521us/sample - loss: 2.1051 - acc: 0.1967 - val_loss: 2.3699 - val_acc: 0.1858
# Epoch 8/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 2.1570 - acc: 0.2115
# Epoch 00008: val_loss did not improve from 2.07105
# 3600/3600 [==============================] - 2s 515us/sample - loss: 2.1565 - acc: 0.2117 - val_loss: 2.0967 - val_acc: 0.1317
# Epoch 9/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 2.1242 - acc: 0.2137
# Epoch 00009: val_loss did not improve from 2.07105
# 3600/3600 [==============================] - 2s 518us/sample - loss: 2.1209 - acc: 0.2108 - val_loss: 2.0895 - val_acc: 0.1000
# Epoch 10/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 2.0739 - acc: 0.2343
# ...
# Epoch 96/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2925 - acc: 0.9114
# Epoch 00096: val_loss did not improve from 0.35450
# 3600/3600 [==============================] - 2s 511us/sample - loss: 0.2942 - acc: 0.9103 - val_loss: 0.4217 - val_acc: 0.8675
# Epoch 97/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.3173 - acc: 0.9035
# Epoch 00097: val_loss did not improve from 0.35450
# 3600/3600 [==============================] - 2s 522us/sample - loss: 0.3160 - acc: 0.9036 - val_loss: 0.3754 - val_acc: 0.8842
# Epoch 98/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2995 - acc: 0.9131
# Epoch 00098: val_loss did not improve from 0.35450
# 3600/3600 [==============================] - 2s 520us/sample - loss: 0.2989 - acc: 0.9136 - val_loss: 0.4242 - val_acc: 0.8650
# Epoch 99/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.3033 - acc: 0.9060
# Epoch 00099: val_loss did not improve from 0.35450
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.3022 - acc: 0.9061 - val_loss: 0.3585 - val_acc: 0.8883
# Epoch 100/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2701 - acc: 0.9285
# Epoch 00100: val_loss did not improve from 0.35450
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2690 - acc: 0.9283 - val_loss: 0.3607 - val_acc: 0.8917
# Epoch 101/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2799 - acc: 0.9143
# Epoch 00101: val_loss did not improve from 0.35450
# 3600/3600 [==============================] - 2s 512us/sample - loss: 0.2793 - acc: 0.9156 - val_loss: 0.4259 - val_acc: 0.8650
# Epoch 102/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2745 - acc: 0.9185
# Epoch 00102: val_loss improved from 0.35450 to 0.34809, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 631us/sample - loss: 0.2761 - acc: 0.9186 - val_loss: 0.3481 - val_acc: 0.8958
# Epoch 103/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2550 - acc: 0.9262
# Epoch 00103: val_loss improved from 0.34809 to 0.34400, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 555us/sample - loss: 0.2566 - acc: 0.9256 - val_loss: 0.3440 - val_acc: 0.8900
# Epoch 104/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2885 - acc: 0.9159
# Epoch 00104: val_loss did not improve from 0.34400
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2868 - acc: 0.9164 - val_loss: 0.4024 - val_acc: 0.8667
# Epoch 105/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2733 - acc: 0.9189
# Epoch 00105: val_loss did not improve from 0.34400
# 3600/3600 [==============================] - 2s 515us/sample - loss: 0.2722 - acc: 0.9186 - val_loss: 0.4074 - val_acc: 0.8700
# Epoch 106/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2748 - acc: 0.9177
# Epoch 00106: val_loss improved from 0.34400 to 0.34277, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 559us/sample - loss: 0.2760 - acc: 0.9169 - val_loss: 0.3428 - val_acc: 0.8967
# Epoch 107/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2529 - acc: 0.9254
# Epoch 00107: val_loss improved from 0.34277 to 0.32830, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 559us/sample - loss: 0.2564 - acc: 0.9242 - val_loss: 0.3283 - val_acc: 0.9033
# Epoch 108/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2594 - acc: 0.9209
# Epoch 00108: val_loss improved from 0.32830 to 0.29569, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 560us/sample - loss: 0.2591 - acc: 0.9214 - val_loss: 0.2957 - val_acc: 0.9158
# Epoch 109/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2621 - acc: 0.9235
# Epoch 00109: val_loss did not improve from 0.29569
# 3600/3600 [==============================] - 2s 515us/sample - loss: 0.2620 - acc: 0.9233 - val_loss: 0.3195 - val_acc: 0.9058
# Epoch 110/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2716 - acc: 0.9224
# Epoch 00110: val_loss did not improve from 0.29569
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.2680 - acc: 0.9236 - val_loss: 0.3763 - val_acc: 0.8783
# Epoch 111/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2523 - acc: 0.9314
# Epoch 00111: val_loss did not improve from 0.29569
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.2518 - acc: 0.9314 - val_loss: 0.3153 - val_acc: 0.9017
# Epoch 112/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2562 - acc: 0.9232
# Epoch 00112: val_loss did not improve from 0.29569
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.2563 - acc: 0.9225 - val_loss: 0.2985 - val_acc: 0.9142
# Epoch 113/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2607 - acc: 0.9209
# Epoch 00113: val_loss did not improve from 0.29569
# 3600/3600 [==============================] - 2s 515us/sample - loss: 0.2617 - acc: 0.9203 - val_loss: 0.4223 - val_acc: 0.8583
# Epoch 114/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2740 - acc: 0.9118
# Epoch 00114: val_loss improved from 0.29569 to 0.29123, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 615us/sample - loss: 0.2735 - acc: 0.9128 - val_loss: 0.2912 - val_acc: 0.9125
# Epoch 115/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2527 - acc: 0.9269
# Epoch 00115: val_loss did not improve from 0.29123
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2523 - acc: 0.9272 - val_loss: 0.3189 - val_acc: 0.9017
# Epoch 116/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2403 - acc: 0.9262
# Epoch 00116: val_loss improved from 0.29123 to 0.27229, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 558us/sample - loss: 0.2426 - acc: 0.9256 - val_loss: 0.2723 - val_acc: 0.9267
# Epoch 117/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2456 - acc: 0.9262
# Epoch 00117: val_loss did not improve from 0.27229
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.2456 - acc: 0.9261 - val_loss: 0.3104 - val_acc: 0.9150
# Epoch 118/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2488 - acc: 0.9229
# Epoch 00118: val_loss did not improve from 0.27229
# 3600/3600 [==============================] - 2s 515us/sample - loss: 0.2481 - acc: 0.9228 - val_loss: 0.3220 - val_acc: 0.8967
# Epoch 119/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2421 - acc: 0.9303
# Epoch 00119: val_loss did not improve from 0.27229
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.2422 - acc: 0.9308 - val_loss: 0.3006 - val_acc: 0.9150
# Epoch 120/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2404 - acc: 0.9314
# Epoch 00120: val_loss improved from 0.27229 to 0.26005, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 626us/sample - loss: 0.2390 - acc: 0.9322 - val_loss: 0.2600 - val_acc: 0.9267
# Epoch 121/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2192 - acc: 0.9409
# Epoch 00121: val_loss did not improve from 0.26005
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.2211 - acc: 0.9403 - val_loss: 0.4102 - val_acc: 0.8742
# Epoch 122/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2237 - acc: 0.9354
# Epoch 00122: val_loss did not improve from 0.26005
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2253 - acc: 0.9356 - val_loss: 0.3902 - val_acc: 0.8808
# Epoch 123/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2207 - acc: 0.9338
# Epoch 00123: val_loss did not improve from 0.26005
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2201 - acc: 0.9339 - val_loss: 0.3038 - val_acc: 0.9033
# Epoch 124/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2250 - acc: 0.9306
# Epoch 00124: val_loss improved from 0.26005 to 0.24273, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 560us/sample - loss: 0.2265 - acc: 0.9311 - val_loss: 0.2427 - val_acc: 0.9350
# Epoch 125/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2146 - acc: 0.9382
# Epoch 00125: val_loss improved from 0.24273 to 0.23761, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 557us/sample - loss: 0.2127 - acc: 0.9397 - val_loss: 0.2376 - val_acc: 0.9317
# Epoch 126/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2193 - acc: 0.9337
# Epoch 00126: val_loss did not improve from 0.23761
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.2194 - acc: 0.9336 - val_loss: 0.2794 - val_acc: 0.9200
# Epoch 127/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2139 - acc: 0.9376
# Epoch 00127: val_loss did not improve from 0.23761
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.2126 - acc: 0.9375 - val_loss: 0.2777 - val_acc: 0.9200
# Epoch 128/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2173 - acc: 0.9382
# Epoch 00128: val_loss did not improve from 0.23761
# 3600/3600 [==============================] - 2s 521us/sample - loss: 0.2178 - acc: 0.9369 - val_loss: 0.2774 - val_acc: 0.9192
# Epoch 129/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2057 - acc: 0.9426
# Epoch 00129: val_loss did not improve from 0.23761
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.2076 - acc: 0.9433 - val_loss: 0.2899 - val_acc: 0.9208
# Epoch 130/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2164 - acc: 0.9418
# Epoch 00130: val_loss did not improve from 0.23761
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2149 - acc: 0.9406 - val_loss: 0.2707 - val_acc: 0.9225
# Epoch 131/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2013 - acc: 0.9418
# Epoch 00131: val_loss did not improve from 0.23761
# 3600/3600 [==============================] - 2s 513us/sample - loss: 0.2049 - acc: 0.9403 - val_loss: 0.2616 - val_acc: 0.9208
# Epoch 132/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2117 - acc: 0.9414
# Epoch 00132: val_loss did not improve from 0.23761
# 3600/3600 [==============================] - 2s 515us/sample - loss: 0.2120 - acc: 0.9406 - val_loss: 0.3046 - val_acc: 0.9008
# Epoch 133/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2062 - acc: 0.9400
# Epoch 00133: val_loss did not improve from 0.23761
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.2053 - acc: 0.9392 - val_loss: 0.2694 - val_acc: 0.9142
# Epoch 134/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2171 - acc: 0.9397
# Epoch 00134: val_loss did not improve from 0.23761
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.2154 - acc: 0.9403 - val_loss: 0.2554 - val_acc: 0.9275
# Epoch 135/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2125 - acc: 0.9365
# Epoch 00135: val_loss did not improve from 0.23761
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.2106 - acc: 0.9369 - val_loss: 0.2473 - val_acc: 0.9275
# Epoch 136/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.1908 - acc: 0.9526
# Epoch 00136: val_loss did not improve from 0.23761
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.1928 - acc: 0.9517 - val_loss: 0.2559 - val_acc: 0.9192
# Epoch 137/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.2056 - acc: 0.9400
# Epoch 00137: val_loss did not improve from 0.23761
# 3600/3600 [==============================] - 2s 519us/sample - loss: 0.2052 - acc: 0.9397 - val_loss: 0.2415 - val_acc: 0.9292
# Epoch 138/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.1986 - acc: 0.9417
# Epoch 00138: val_loss improved from 0.23761 to 0.21040, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 642us/sample - loss: 0.1979 - acc: 0.9417 - val_loss: 0.2104 - val_acc: 0.9425
# Epoch 139/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.1911 - acc: 0.9446
# Epoch 00139: val_loss did not improve from 0.21040
# 3600/3600 [==============================] - 2s 522us/sample - loss: 0.1934 - acc: 0.9431 - val_loss: 0.2150 - val_acc: 0.9350
# Epoch 140/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.1924 - acc: 0.9429
# Epoch 00140: val_loss did not improve from 0.21040
# 3600/3600 [==============================] - 2s 514us/sample - loss: 0.1947 - acc: 0.9422 - val_loss: 0.2418 - val_acc: 0.9325
# Epoch 141/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2196 - acc: 0.9374
# Epoch 00141: val_loss did not improve from 0.21040
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.2198 - acc: 0.9369 - val_loss: 0.2220 - val_acc: 0.9433
# Epoch 142/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2047 - acc: 0.9400
# Epoch 00142: val_loss did not improve from 0.21040
# 3600/3600 [==============================] - 2s 520us/sample - loss: 0.2025 - acc: 0.9406 - val_loss: 0.2305 - val_acc: 0.9392
# Epoch 143/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.1932 - acc: 0.9435
# Epoch 00143: val_loss did not improve from 0.21040
# 3600/3600 [==============================] - 2s 522us/sample - loss: 0.1924 - acc: 0.9444 - val_loss: 0.2481 - val_acc: 0.9233
# Epoch 144/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.2203 - acc: 0.9297
# Epoch 00144: val_loss did not improve from 0.21040
# 3600/3600 [==============================] - 2s 519us/sample - loss: 0.2196 - acc: 0.9308 - val_loss: 0.2995 - val_acc: 0.9125
# Epoch 145/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.1869 - acc: 0.9462
# Epoch 00145: val_loss did not improve from 0.21040
# 3600/3600 [==============================] - 2s 516us/sample - loss: 0.1921 - acc: 0.9453 - val_loss: 0.3321 - val_acc: 0.9117
# Epoch 146/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.1916 - acc: 0.9460
# Epoch 00146: val_loss did not improve from 0.21040
# 3600/3600 [==============================] - 2s 517us/sample - loss: 0.1919 - acc: 0.9461 - val_loss: 0.2485 - val_acc: 0.9242
# Epoch 147/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.1958 - acc: 0.9374
# Epoch 00147: val_loss did not improve from 0.21040
# 3600/3600 [==============================] - 2s 518us/sample - loss: 0.1987 - acc: 0.9369 - val_loss: 0.2643 - val_acc: 0.9125
# Epoch 148/150
# 3400/3600 [===========================>..] - ETA: 0s - loss: 0.1854 - acc: 0.9429
# Epoch 00148: val_loss did not improve from 0.21040
# 3600/3600 [==============================] - 2s 512us/sample - loss: 0.1869 - acc: 0.9428 - val_loss: 0.2631 - val_acc: 0.9208
# Epoch 149/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.1901 - acc: 0.9457
# Epoch 00149: val_loss did not improve from 0.21040
# 3600/3600 [==============================] - 2s 519us/sample - loss: 0.1883 - acc: 0.9469 - val_loss: 0.2591 - val_acc: 0.9183
# Epoch 150/150
# 3500/3600 [============================>.] - ETA: 0s - loss: 0.1773 - acc: 0.9503
# Epoch 00150: val_loss improved from 0.21040 to 0.20794, saving model to saved_models/weights.best.basic_mlp.hdf5
# 3600/3600 [==============================] - 2s 638us/sample - loss: 0.1793 - acc: 0.9489 - val_loss: 0.2079 - val_acc: 0.9417
# 1200/1200 [==============================] - 0s 254us/sample - loss: 0.2079 - acc: 0.9417
# [0.2079441479841868, 0.94166666]

# %% [markdown]
# # (6) Тестирање на моделот
#
# Тестирање на моделот

# %%
# Иницијализација на променливите каде ќе бидат вчитани тест податоците
runs_per_block = [[i for i in range(3)] for j in range(15)] # Covek, Sesija

for participant in range(PARTICIPANT_START, PARTICIPANT_END): # Итерација низ секој испитен примерок
  print(f"============================================================ Учесник ({participant}) ============================================================")
  index = participant - PARTICIPANT_START 
  
  test_data, test_events = load_test_data(participant)
  runs_per_block = load_runs_per_block(participant)

  to_predict_data = reshape(test_data)
  predictions = models[index].predict(to_predict_data)

  print_test_data_info(participant, test_data, test_events, runs_per_block, predictions, index)

  int_pred = np.argmax(predictions, axis=1)
  int_ytest = np.argmax(y_test, axis=1)

  session_start = 0
  start_prediction_index = 0
  end_prediction_index = 0
  for session in range(0, 3):
    print(f"Сесија ({session}): ", end='')
    for block in range(0, 50):    
      events_per_block = runs_per_block[participant-1][session]

      start_prediction_index = session_start + (block*events_per_block)*8
      end_prediction_index = session_start + ((block+1)*events_per_block)*8

      block_prediction = int_pred[start_prediction_index:end_prediction_index]
      prediction = np.bincount(block_prediction).argmax()

      if (block != 49):
        print(str(prediction) + ",", end="")
      else:
        print(str(prediction))  
    session_start = end_prediction_index
  print(f"============================================================ Учесник ({participant}) ============================================================\n\n")
# Out:
# ============================================================ Учесник (3) ============================================================
# Вчитување тест податоци од испитниот примерок (учесник) 3...
# Тест податоците од испитниот примерок (учесник) 3 се вчитани.
#
# SBJ03| Test_data: (350, 7600)
# SBJ03| Test_events: 7600
# SBJ03 / S01| Runs per block: 6
# SBJ03 / S02| Runs per block: 6
# SBJ03 / S03| Runs per block: 7
# SBJ03| Predictions: 7600
#
# Сесија (0): 2,2,3,3,2,2,2,2,2,4,3,6,2,2,2,4,5,2,2,3,4,2,2,3,3,4,2,3,2,2,3,3,2,2,2,3,3,2,2,3,2,3,2,2,2,2,3,2,2,2
# Сесија (1): 0,0,6,6,6,6,0,5,6,0,5,0,5,5,5,5,6,5,5,5,0,5,0,5,5,5,5,0,5,5,5,5,5,5,5,0,5,0,0,5,0,6,0,0,0,5,5,5,5,5
# Сесија (2): 5,3,7,7,4,6,7,7,7,3,0,0,7,7,5,3,0,0,3,7,5,7,0,0,0,0,3,3,3,5,0,0,3,0,3,3,3,0,0,3,0,7,3,4,7,3,0,0,0,7
# ============================================================ Учесник (3) ============================================================
#
#
# ============================================================ Учесник (4) ============================================================
# Вчитување тест податоци од испитниот примерок (учесник) 4...
# Тест податоците од испитниот примерок (учесник) 4 се вчитани.
#
# SBJ04| Test_data: (350, 6800)
# SBJ04| Test_events: 6800
# SBJ04 / S01| Runs per block: 5
# SBJ04 / S02| Runs per block: 5
# SBJ04 / S03| Runs per block: 7
# SBJ04| Predictions: 6800
#
# Сесија (0): 0,0,0,0,1,0,0,4,4,4,0,1,0,0,0,0,0,0,5,0,0,5,2,1,1,5,1,4,5,5,1,1,0,0,5,1,5,1,5,2,0,0,0,6,6,0,5,5,5,0
# Сесија (1): 6,6,3,6,5,4,2,4,6,7,6,4,6,2,6,2,2,5,5,3,4,4,4,4,4,5,3,4,0,4,5,6,3,6,2,5,4,5,4,2,5,6,0,4,4,1,4,4,1,3
# Сесија (2): 6,2,6,2,5,5,0,4,2,0,2,5,5,2,5,2,5,5,2,6,6,3,3,6,2,2,2,2,6,3,0,6,0,2,2,5,0,0,0,0,5,5,3,0,0,3,3,2,0,0
# ============================================================ Учесник (4) ============================================================
